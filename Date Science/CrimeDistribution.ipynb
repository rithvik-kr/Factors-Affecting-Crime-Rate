# %%
import pandas as pd
from statsmodels.graphics.gofplots import qqplot
import pylab as py
import statsmodels.api as sm
import numpy as np

# %%
df_2009 = pd.read_csv("CrimeRate_2009.csv")
df_2010 = pd.read_csv("CrimeRate_2010.csv")
df_2011 = pd.read_csv("CrimeRate_2011.csv")
df_20091 = pd.read_csv("CrimeRate_2009_1.csv")
# df_2018 = pd.read_csv("CrimeRate_2018.csv")
# df_2019 = pd.read_csv("CrimeRate_2019.csv")
# df_2020 = pd.read_csv("CrimeRate_2020.csv")

# %%
df_2009.sort_values('STATE/UT', inplace=True, ignore_index=True)

# %%
df_2009.dropna(inplace=True, axis=0)
df_2010.dropna(inplace=True)
df_2011.dropna(inplace=True)
df_20091.dropna(inplace=True)
# df_2018.dropna(inplace=True)
# df_2019.dropna(inplace=True)
# df_2020.dropna(inplace=True)

# %%
# df_2009.loc[0, ["STATE/UT"]] = df_2010.iloc[0]["STATE/UT"]
# df_2018.loc[0, ["STATE/UT"]] = df_2010.iloc[0]["STATE/UT"]
# df_2019.loc[0, ["STATE/UT"]] = df_2010.iloc[0]["STATE/UT"]
# df_2020.loc[0, ["STATE/UT"]] = df_2010.iloc[0]["STATE/UT"]

# %%
for i in range(len(df_2009)):
    df_2009.loc[i, ["STATE/UT"]] = df_2009.iloc[i]["STATE/UT"] + "_2009"
    df_20091.loc[i, ["STATE/UT"]] = df_20091.iloc[i]["STATE/UT"] + "_2009_1"    
    df_2010.loc[i, ["STATE/UT"]] = df_2010.iloc[i]["STATE/UT"] + "_2010"
    df_2011.loc[i, ["STATE/UT"]] = df_2011.iloc[i]["STATE/UT"] + "_2011"
#     df_2018.loc[i, ["STATE/UT"]] = df_2018.iloc[i]["STATE/UT"] + "_2018"
#     df_2019.loc[i, ["STATE/UT"]] = df_2019.iloc[i]["STATE/UT"] + "_2019"
#     df_2020.loc[i, ["STATE/UT"]] = df_2020.iloc[i]["STATE/UT"] + "_2020"

# %%
df_all = pd.concat([df_20091, df_2009, df_2010, df_2011])
display(df_all)
# Out:
#     SL                  STATE/UT       C1       C2      C3      C4      C5  \
# 0    1     ANDHRA PRADESH_2009_1   4604.0   3065.0   240.0     0.0  2521.0
# 1    2  ARUNACHAL PRADESH_2009_1     83.0     48.0     4.0     0.0    61.0
# 2    3              ASSAM_2009_1   1866.0    559.0    56.0     0.0  2875.0
# 3    4              BIHAR_2009_1   5394.0   6169.0   385.0     0.0  4727.0
# 4    5       CHHATTISGARH_2009_1   1739.0   1350.0    31.0     0.0   373.0
# ..  ..                       ...      ...      ...     ...     ...     ...
# 30  31           TAMIL NADU_2011   4128.0   8254.0    31.0   837.0     0.0
# 31  32              TRIPURA_2011    306.0    107.0     0.0   258.0     0.0
# 32  33        UTTAR PRADESH_2011  14093.0  12240.0  3801.0  3571.0     0.0
# 33  34          UTTARAKHAND_2011    311.0    302.0    92.0   149.0     0.0
# 34  35          WEST BENGAL_2011   3363.0   2243.0   603.0  1870.0     0.0
#
#         C6       C7       C8  ...     C21      C22      C23     C24      C25  \
# 0   1889.0    632.0    465.0  ...  5441.0   4178.0  19018.0     0.0  11301.0
# 1     38.0     23.0     47.0  ...    70.0      2.0     12.0     0.0     71.0
# 2   2392.0    483.0    915.0  ...  1614.0     15.0   5753.0     1.0   2639.0
# 3   2397.0   2330.0   1994.0  ...   795.0     16.0   4939.0    17.0   3455.0
# 4    267.0    106.0    406.0  ...  1817.0    235.0   2462.0     0.0   1970.0
# ..     ...      ...      ...  ...     ...      ...      ...     ...      ...
# 30   837.0   2153.0   1778.0  ...   700.0  37934.0    336.0  2092.0    490.0
# 31   258.0    153.0    113.0  ...    31.0   2571.0     57.0   455.0      9.0
# 32  3571.0  21986.0  19299.0  ...  1323.0  26108.0   9795.0  5252.0      3.0
# 33   149.0    334.0    295.0  ...     9.0   1123.0    233.0   153.0    111.0
# 34  1870.0   3316.0   2748.0  ...   409.0  16308.0   1118.0  2243.0    225.0
#
#         C26       C27      C28       C29       C30
# 0   68539.0  234920.0      NaN       NaN       NaN
# 1     831.0    2817.0      NaN       NaN       NaN
# 2   16705.0   71627.0      NaN       NaN       NaN
# 3   87779.0  205005.0      NaN       NaN       NaN
# 4   24849.0   67070.0      NaN       NaN       NaN
# ..      ...       ...      ...       ...       ...
# 30   2879.0       0.0  13064.0  109156.0  222124.0
# 31   1776.0       0.0    250.0    2483.0   10062.0
# 32  33465.0       0.0  12935.0  136646.0  384605.0
# 33    382.0       0.0    592.0    2713.0   10666.0
# 34  17583.0       0.0   2002.0   50398.0  143608.0
#
# [150 rows x 32 columns]

# %%
display(df_20091)
# Out:
#      SL                  STATE/UT       C1       C2      C3   C4       C5  \
# 0     1     ANDHRA PRADESH_2009_1   4604.0   3065.0   240.0  0.0   2521.0
# 1     2  ARUNACHAL PRADESH_2009_1     83.0     48.0     4.0  0.0     61.0
# 2     3              ASSAM_2009_1   1866.0    559.0    56.0  0.0   2875.0
# 3     4              BIHAR_2009_1   5394.0   6169.0   385.0  0.0   4727.0
# 4     5       CHHATTISGARH_2009_1   1739.0   1350.0    31.0  0.0    373.0
# 5     6                GOA_2009_1     88.0     88.0    12.0  0.0     40.0
# 6     7            GUJARAT_2009_1   2130.0   2199.0    39.0  0.0   1848.0
# 7     8            HARYANA_2009_1   1842.0   1685.0   103.0  0.0    909.0
# 8     9   HIMACHAL PRADESH_2009_1    191.0    146.0    26.0  0.0    148.0
# 9    10    JAMMU & KASHMIR_2009_1    432.0    947.0    20.0  0.0    725.0
# 10   11          JHARKHAND_2009_1   1975.0   1816.0   110.0  0.0    836.0
# 11   12          KARNATAKA_2009_1   3287.0   3978.0   112.0  0.0   1094.0
# 12   13             KERALA_2009_1    710.0   1176.0   157.0  0.0    436.0
# 13   14     MADHYA PRADESH_2009_1   5265.0   6401.0   218.0  6.0   1630.0
# 14   15        MAHARASHTRA_2009_1   5904.0   6532.0   163.0  0.0   2043.0
# 15   16            MANIPUR_2009_1     85.0    103.0     0.0  0.0    119.0
# 16   17          MEGHALAYA_2009_1    130.0     33.0     9.0  0.0     58.0
# 17   18            MIZORAM_2009_1     29.0     15.0    10.0  1.0      4.0
# 18   19           NAGALAND_2009_1     27.0     31.0     5.0  0.0     73.0
# 19   20             ODISHA_2009_1   1859.0   2037.0    66.0  0.0   1013.0
# 20   21             PUNJAB_2009_1   1489.0   2520.0   157.0  0.0    816.0
# 21   22          RAJASTHAN_2009_1   2297.0   4156.0   102.0  0.0   1828.0
# 22   23             SIKKIM_2009_1     17.0     11.0     4.0  0.0      7.0
# 23   24         TAMIL NADU_2009_1   3602.0   5728.0    20.0  0.0   1779.0
# 24   25            TRIPURA_2009_1    206.0     75.0     4.0  0.0    176.0
# 25   26      UTTAR PRADESH_2009_1  12365.0  10499.0  3551.0  0.0  12393.0
# 26   27        UTTARAKHAND_2009_1    388.0    324.0    67.0  0.0    213.0
# 27   28        WEST BENGAL_2009_1   3498.0   1590.0   645.0  0.0   2291.0
# 29   29         CHANDIGARH_2009_1     38.0      5.0     7.0  0.0     16.0
# 30   30         D&N HAVELI_2009_1     51.0     63.0    15.0  0.0     32.0
# 31   31        DAMAN & DIU_2009_1      7.0     12.0     4.0  0.0     16.0
# 32   32              DELHI_2009_1     11.0     12.0     6.0  0.0      4.0
# 33   33        LAKSHADWEEP_2009_1    889.0    716.0   103.0  0.0    625.0
# 34   34         PUDUCHERRY_2009_1      0.0      9.0     0.0  0.0      0.0
# 35   35                PUDUCHERRY    167.0     87.0    28.0  0.0     24.0
# 28  NaN        A&N ISLANDS_2009_1      NaN      NaN     NaN  NaN      NaN
#
#          C6      C7      C8  ...     C18      C19     C20     C21     C22  \
# 0    1889.0   632.0   465.0  ...  1230.0  65042.0  1220.0  5441.0  4178.0
# 1      38.0    23.0    47.0  ...    25.0    739.0     0.0    70.0     2.0
# 2    2392.0   483.0   915.0  ...   877.0   9487.0   297.0  1614.0    15.0
# 3    2397.0  2330.0  1994.0  ...  1120.0  26915.0  2908.0   795.0    16.0
# 4     267.0   106.0   406.0  ...   324.0  16261.0   353.0  1817.0   235.0
# 5      18.0    22.0    16.0  ...    34.0    316.0     3.0    35.0    10.0
# 6    1494.0   354.0  1016.0  ...   457.0  20253.0    53.0  1025.0   188.0
# 7     530.0   379.0   540.0  ...   175.0  10220.0   633.0   553.0   717.0
# 8     102.0    46.0    28.0  ...    84.0   1919.0     3.0   345.0    40.0
# 9     696.0    29.0    10.0  ...   123.0    727.0    46.0  2044.0   512.0
# 10    397.0   439.0   788.0  ...   240.0   6023.0   562.0   327.0    38.0
# 11    506.0   588.0   868.0  ...   375.0  30678.0   666.0  3159.0    40.0
# 12    202.0   234.0   586.0  ...   485.0  27732.0    32.0  3238.0   456.0
# 13   1060.0   570.0   701.0  ...  1233.0  84031.0  2474.0  7567.0  1047.0
# 14   1388.0   655.0  4062.0  ...  1637.0  55593.0  1233.0  3938.0  1337.0
# 15     95.0    24.0     0.0  ...    14.0    199.0     0.0    40.0     1.0
# 26    890.0   0.0    572.0    3143.0   11829.0
# 27  13884.0   7.0   2456.0   38240.0  113613.0
# 29     35.0   0.0      1.0     417.0    1035.0
# 30     28.0   0.0      8.0     880.0    2354.0
# 31      0.0   0.0     13.0     153.0     694.0
# 32      4.0   0.0     28.0      97.0     452.0
# 33    658.0   0.0    708.0   14848.0   36263.0
# 34      2.0   0.0      0.0      17.0     230.0
# 35     21.0   0.0    243.0    2418.0    6502.0
# 28      NaN   NaN      NaN       NaN       NaN
#
# [36 rows x 29 columns]

# %%
# df_all.sort_values(by=['STATE/UT'], inplace=True)
df_all.dropna(inplace=True, axis=1)
# df_all.drop(['C27'], axis=1, inplace=True)
df_all.head(100)

# %%
df_all['GraveCrimesNo'] = (df_all.iloc[:, 2:11].sum(axis=1))
df_all['PettyCrimesNo'] = (df_all.iloc[:, 11:29].sum(axis=1))
df_all['GraveCrime'] = df_all['GraveCrimesNo']/(df_all['PettyCrimesNo']+df_all['GraveCrimesNo'])
df_all['PettyCrime'] = df_all['PettyCrimesNo']/(df_all['PettyCrimesNo']+df_all['GraveCrimesNo'])
display(df_all)

# %%
df_2009, df_2010, df_2011 = np.array_split(df_all, 3)

# %%
df_all['GraveCrime'].hist(legend=True)

# %%
sm.qqplot(df_all.loc[:, 'GraveCrime'], line ='s')
py.show()

# %%
df_2009.plot.bar(x='STATE/UT', y=["PettyCrime", "GraveCrime"],  stacked=True,  width = 0.4,alpha=0.5, figsize=[20, 4])

# %%
df_2010.plot.bar(x='STATE/UT', y=["PettyCrime", "GraveCrime"],  stacked=True,  width = 0.4,alpha=0.5, figsize=[20, 4])

# %%
df_2011.plot.bar(x='STATE/UT', y=["PettyCrime", "GraveCrime"],  stacked=True,  width = 0.4,alpha=0.5, figsize=[20, 4])

# %%
# from scipy.stats import shapiro
# import matplotlib.pyplot as plt
# from statsmodels.graphics.gofplots import qqplot
# from scipy.stats import normaltest
# from scipy.stats import anderson
# for i in range(int(len(df_all)/3)):
#     df_1 = df_all.iloc[i*3:i*3+3, :]
# #     try:
#     print(df_1.iloc[:, [0,1,30]])
#     print('\nQ-Q Plot')
#     qqplot(df_1['CrimeRatio'], line='s')
#     plt.show()
#     print('\nShapiro Wilk Test')
#     stat, p = shapiro(df_1['CrimeRatio'])
#     print('Statistics=%.3f, p=%.3f ' % (stat, p))
#     # interpret
#     alpha = 0.05
#     if p > alpha:
#         print('Sample looks Gaussian (fail to reject H0)\n\n')
#     else:
#         print('Sample does not look Gaussian (reject H0)\n\n')
#     print('Anderson-Darling Test\n')
#     result = anderson(df_1['CrimeRatio'])
#     print('Statistic: %.3f' % result.statistic)
#     p = 0
#     for i in range(len(result.critical_values)):
#         sl, cv = result.significance_level[i], result.critical_values[i]
#         if result.statistic < result.critical_values[i]:
#             print('%.3f: %.3f, data looks normal (fail to reject H0)\n\n' % (sl, cv))
#         else:
#             print('%.3f: %.3f, data does not look normal (reject H0)\n\n' % (sl, cv))
# #     except:
# #         print(df_1)
